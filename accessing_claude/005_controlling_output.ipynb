# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.77.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: python-dotenv in /usr/lib/python3/dist-packages (1.0.1)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic) (1.9.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from anthropic)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/lib/python3/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.6)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-extensions<5,>=4.10 (from anthropic)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.77.0-py3-none-any.whl (397 kB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (360 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, sniffio, jiter, h11, docstring-parser, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, anthropic
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Not uninstalling typing-extensions at /usr/lib/python3/dist-packages, outside environment /home/installer/Documents/Personal/Anthropic-Courses/.venv
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
# Successfully installed annotated-types-0.7.0 anthropic-0.77.0 anyio-4.12.1 docstring-parser-0.17.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.13.0 pydantic-2.12.5 pydantic-core-2.41.5 sniffio-1.3.1 typing-extensions-4.15.0 typing-inspection-0.4.2
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: /home/installer/Documents/Personal/Anthropic-Courses/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})

def chat(messages, system=None, temperature=0, stop_sequences=None):
    if stop_sequences is None:
        stop_sequences = []
    params = {
        "model": model,
        "max_tokens": 1024,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }
    if system:
        params["system"] = system
    message = client.messages.create(**params)
    return message.content[0].text

# %% [markdown]
# ## Prefilled Assistant Messages

# %%
messages = []
add_user_message(messages, "Is tea or coffee better at breakfast?")
add_assistant_message(messages, "Coffee is better because")
answer = chat(messages)
answer
# Out:
# ' it has more caffeine to help you wake up and start your day. Tea has less caffeine and is better for later in the day when you want something more relaxing.'

# %% [markdown]
# ## Stop Sequences

# %%
messages = []
add_user_message(messages, "Count from 1 to 10")
answer = chat(messages, stop_sequences=["5"])
answer
# Out:
# '1, 2, 3, 4, '

# %% [markdown]
# ## Structured Data

# %%
import json
messages = []

add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")

text = chat(messages, stop_sequences=["```"])
clean_json = json.loads(text.strip())
